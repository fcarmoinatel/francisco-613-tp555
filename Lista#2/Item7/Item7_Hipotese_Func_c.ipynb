# %%
# Sequência de bibliotecas necessárias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %matplotlib notebook

# %%
# Entradas de Vetor coluna e vetor linha + leitura do arquivo training.csv

df = pd.read_csv('training.csv', header=None)
x_l = df[0].to_numpy()
y_l = df[1].to_numpy()

arr1 = [x_l]
arr2 = [y_l]
x = np.transpose(arr1)
y = np.transpose(arr2)
 
fig = plt.figure(figsize=(10,10))
plt.plot(x, y, 'b.')
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Valores de Treinamento')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 1.0, 'Valores de Treinamento')

# %%
M = 1000

np.random.seed(1234)

X = np.c_[np.ones((M, 1)), x, x**2, x**3]

a_opt = np.linalg.pinv(np.transpose(X).dot(X)).dot(np.transpose(X).dot(y))
yhat = a_opt[0, 0] + a_opt[1, 0]*x + a_opt[2, 0]*x**2 + a_opt[3, 0]*x**3
Joptimum = (1/M)*np.sum(np.power((y - yhat), 2))

# %%
alpha = 0.00045
n_iterations = 100000
a = np.zeros((4,1))
a[0] = -10;
a[1] = -10;
a[2] = -10;
a[3] = -10;

Jgd = np.zeros(n_iterations+1)

Jgd[0] = (1/M)*sum(np.power(y - X.dot(a), 2))

iteration = 0

while iteration < n_iterations:
    gradients = -2/M * X.T.dot(y - X.dot(a))
    
    a = a - alpha * gradients
    
    Jgd[iteration+1] = (1/M)*sum(np.power( (y - X.dot(a)) , 2))
    
    iteration = iteration + 1

# %%
# Sequência de exibição de valores encontrados

print('a0_opt: ' + str(a_opt[0, 0]))
print('a1_opt: ' + str(a_opt[1, 0]))
print('a2_opt: ' + str(a_opt[2, 0]))
print('a3_opt: ' + str(a_opt[3, 0]))

print('a0_gd: ' + str(a[0, 0]))
print('a1_gd: ' + str(a[1, 0]))
print('a2_gd: ' + str(a[2, 0]))
print('a3_gd: ' + str(a[3, 0]))
# Out:
# a0_opt: 0.9928568135454903
# a1_opt: -2.013607794117668
# a2_opt: 0.4986687501112793
# a3_opt: 0.0003389545838047292
# a0_gd: 0.9928568135452055
# a1_gd: -2.0136077941175126
# a2_gd: 0.4986687501112986
# a3_gd: 0.00033895458379597313

# %%
# Parametros para o print da figura
fig = plt.figure(figsize=(7,7))
plt.plot(x, y, 'g.')
plt.plot(x, yhat , 'r.')
plt.xlabel('x values')
plt.ylabel('y vs. h')
plt.title('Dados originais (y) versus Dados Estimados (h)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
fig = plt.figure(figsize=(7,7))
plt.plot(np.arange(0, iteration), Jgd[0:iteration])
plt.xlim((0, iteration))
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('$J_e$')
plt.title('Erros versus quantidade de interações')
plt.show()
plt.savefig("Erro_versus_interações_Item7c.png", dpi=600)
# Out:
# <img src="data:image/png;base64,..." width="700">
